# %% [markdown]
# # BHARAT INTERN

# %% [markdown]
# # DATA SCIENCE INTERSHIP

# %% [markdown]
# # INTERN NAME - AKANKSHA TRIPATHI

# %% [markdown]
# # TASK - 1

# %% [markdown]
# # STOCK PREDICTION

# %% [markdown]
# ## TO PREDICT THE STOCK PRICE OF ANY COMPANY USING LSTM. USE ONLY JUPYTER NOTEBOOK CODE.

# %% [markdown]
# ### A deep learning project in which the model was trained using LSTM layers and Tata Stock prices were predicted and compared with thier actual values.

# %% [markdown]
# ### To build the stock price prediction model, we will use the NSE TATA GLOBAL dataset. This is a dataset of Tata Beverages from Tata Global Beverages Limited, National Stock Exchange of India: Tata Global Dataset

# %% [markdown]
# # Import Libaries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import io
import requests 
import datetime

# %% [markdown]
# # Import Datasets

# %%
df=pd.read_csv('NSE-TATAGLOBAL11.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df1 = pd.read_csv('NSE-TATAGLOBAL11.csv')

# %%
df1.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %% [markdown]
# # Shape of data

# %%
df.shape
# Out:
# (1235, 8)

# %% [markdown]
# # Gathering information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  1235 non-null   object
#  1   Open                  1235 non-null   float64
#  2   High                  1235 non-null   float64
#  3   Low                   1235 non-null   float64
#  4   Last                  1235 non-null   float64
#  5   Close                 1235 non-null   float64
#  6   Total Trade Quantity  1235 non-null   float64
#  7   Turnover (Lacs)       1235 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# 75%            3.095788e+06      5852.600000
# max            2.919102e+07     55755.080000

# %%
df.dtypes
# Out:
# Date                     object
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity    float64
# Turnover (Lacs)         float64
# dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Total percentage of data is missing

# %%
missing_values_count = df.isnull().sum()

total_cells = np.product(df.shape)

total_missing = missing_values_count.sum()

percentage_missing = (total_missing/total_cells)*100

print(percentage_missing)
# Out:
# 0.0

# %%
NAN = [(c, df[c].isnull().mean()*100) for c in df]
NAN = pd.DataFrame(NAN, columns=['column_name', 'percentage'])
NAN
# Out:
#             column_name  percentage
# 0                  Date         0.0
# 1                  Open         0.0
# 2                  High         0.0
# 3                   Low         0.0
# 4                  Last         0.0
# 5                 Close         0.0
# 6  Total Trade Quantity         0.0
# 7       Turnover (Lacs)         0.0

# %% [markdown]
# # Data Visualisation

# %%
sns.set(rc = {'figure.figsize': (20, 5)})
df['Open'].plot(linewidth = 1,color='blue')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
cols_plot = ['Open','High','Low','Last','Close']
axes = df[cols_plot].plot(alpha = 1, figsize=(20, 30), subplots = True)

for ax in axes:
    ax.set_ylabel('Variation')

# %% [markdown]
# # Sort the dataset on date time and filter “Date” and “Open” columns

# %%
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']
df
# Out:
#                  Date    Open    High     Low    Last   Close  \
# Date
# 2018-10-08 2018-10-08  208.00  222.25  206.85  216.00  215.15
# 2018-10-05 2018-10-05  217.00  218.60  205.90  210.25  209.20
# 2018-10-04 2018-10-04  223.50  227.80  216.15  217.25  218.20
# 2018-10-03 2018-10-03  230.00  237.50  225.75  226.45  227.60
# 2018-10-01 2018-10-01  234.55  234.60  221.05  230.30  230.90
# ...               ...     ...     ...     ...     ...     ...
# 2013-10-14 2013-10-14  160.85  161.45  157.70  159.30  159.45
# 2013-10-11 2013-10-11  161.15  163.45  159.00  159.80  160.05
# 2013-10-10 2013-10-10  156.00  160.80  155.85  160.30  160.15
# 2013-10-09 2013-10-09  155.70  158.20  154.15  155.30  155.55
# 2013-10-08 2013-10-08  157.00  157.80  155.20  155.80  155.80
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-10-08             4642146.0         10062.83
# 2018-10-05             3519515.0          7407.06
# 2018-10-04             1728786.0          3815.79
# 2018-10-03             1708590.0          3960.27
# 2018-10-01             1534749.0          3486.05
# ...                          ...              ...
# 2013-10-14             1281419.0          2039.09
# 2013-10-11             1880046.0          3030.76
# 2013-10-10             3124853.0          4978.80
# 2013-10-09             2049580.0          3204.49
# 2013-10-08             1720413.0          2688.94
#
# [1235 rows x 8 columns]

# %%
del df["Date"]

# %%
df.dtypes
# Out:
# Open                    float64
# High                    float64
# Low                     float64
# Last                    float64
# Close                   float64
# Total Trade Quantity    float64
# Turnover (Lacs)         float64
# dtype: object

# %% [markdown]
# # 7 day rolling mean

# %%
df.rolling(7).mean().head(10)
# Out:
#                   Open        High         Low        Last       Close  \
# Date
# 2018-10-08         NaN         NaN         NaN         NaN         NaN
# 2018-10-05         NaN         NaN         NaN         NaN         NaN
# 2018-10-04         NaN         NaN         NaN         NaN         NaN
# 2018-10-03         NaN         NaN         NaN         NaN         NaN
# 2018-10-01         NaN         NaN         NaN         NaN         NaN
# 2018-09-28         NaN         NaN         NaN         NaN         NaN
# 2018-09-27  225.950000  230.500000  219.571429  223.935714  224.007143
# 2018-09-26  230.521429  233.035714  223.235714  226.650000  226.735714
# 2018-09-25  232.850000  235.628571  226.964286  230.364286  230.578571
# 2018-09-24  234.285714  237.257143  229.050000  232.757143  232.735714
#
#             Total Trade Quantity  Turnover (Lacs)
# Date
# 2018-10-08                   NaN              NaN
# 2018-10-05                   NaN              NaN
# 2018-10-04                   NaN              NaN
# 2018-10-03                   NaN              NaN
# 2018-10-01                   NaN              NaN
# 2018-09-28                   NaN              NaN
# 2018-09-27          3.040937e+06      6822.042857
# 2018-09-26          2.697903e+06      6134.295714
# 2018-09-25          2.530739e+06      5862.415714
# 2018-09-24          2.772843e+06      6460.095714

# %%
df['Open'].plot(figsize=(20,8),alpha = 1)
df.rolling(window=30).mean()['Close'].plot(alpha = 1)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Optional specify a minimum numbe2of periods

# %%
df['Close: 30 Day Mean'] = df['Close'].rolling(window=30).mean()
df[['Close','Close: 30 Day Mean']].plot(figsize=(20,8),alpha = 1)
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].expanding(min_periods=1).mean().plot(figsize=(20,8),alpha = 1)
# Out:
# <Axes: xlabel='Date'>

# %%
df2=df1.reset_index()['Open']
df2
# Out:
# 0       208.00
# 1       217.00
# 2       223.50
# 3       230.00
# 4       234.55
#          ...
# 1230    160.85
# 1231    161.15
# 1232    156.00
# 1233    155.70
# 1234    157.00
# Name: Open, Length: 1235, dtype: float64

# %%
plt.plot(df2)

# %% [markdown]
# # LSTM are sensitive to the scale of the data. so we apply MinMax scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df2=scaler.fit_transform(np.array(df2).reshape(-1,1))
print(df2)
# Out:
# [[0.46728972]
#  [0.50734312]
#  [0.53627058]
#  ...
#  [0.23587005]
#  [0.23453494]
#  [0.24032043]]

# %% [markdown]
# ## splitting dataset into train and test split

# %%
train_size=int(len(df2)*0.75)
test_size=len(df2)-train_size
train_data,test_data=df2[0:train_size,:],df2[train_size:len(df2),:1]

# %%
train_size,test_size
# Out:
# (926, 309)

# %%
train_data,test_data
# Out:
# (array([[0.46728972],
#         [0.50734312],
#         [0.53627058],
#         [0.56519804],
#         [0.58544726],
#         [0.58322207],
#         [0.58544726],
#         [0.60970182],
#         [0.57988429],
#         [0.58099688],
#         [0.58744993],
#         [0.59167779],
#         [0.60035603],
#         [0.57921673],
#         [0.53604806],
#         [0.50445038],
#         [0.5318202 ],
#         [0.5318202 ],
#         [0.52514464],
#         [0.53849577],
#         [0.52959502],
#         [0.60169114],
#         [0.59190031],
#         [0.59635069],
#         [0.58900757],
#         [0.582332  ],
#         [0.59635069],
#         [0.57320872],
#         [0.58522474],
#         [0.61103694],
#         [0.64040943],
#         [0.18246551],
#         [0.1800178 ],
#         [0.18780596],
#         [0.20048954],
#         [0.2082777 ],
#         [0.20694259],
#         [0.21806854],
#         [0.22696929],
#         [0.22963952],
#         [0.22096128],
#         [0.22696929],
#         [0.23141967],
#         [0.23097463],
#         [0.22340899],
#         [0.22162884],
#         [0.23809524],
#         [0.23720516],
#         [0.24855363],
#         [0.22830441],
#         [0.22429907],
#         [0.23141967],
#         [0.22007121],
#         [0.21984869],
#         [0.21361816],
#         [0.2247441 ],
#         [0.21028037],
#         [0.19982198],
#         [0.20516244],
#         [0.21361816],
#         [0.21806854],
#         [0.22674677],
#         [0.21584335],
#         [0.21584335],
#         [0.22162884],
#         [0.22207388],
#         [0.22162884],
#         [0.21206053],
#         [0.21562083],
#         [0.21562083],
#         [0.21673342],
#         [0.20872274],
#         [0.21361816],
#         [0.22207388],
#         [0.18202047],
#         [0.1893636 ],
#         [0.19581664],
#         [0.18602581],
#         [0.19003115],
#         [0.1717846 ],
#         [0.16288385],
#         [0.16555407],
#         [0.16844682],
#         [0.16733422],
#         [0.1753449 ],
#         [0.17801513],
#         [0.18224299],
#         [0.16955941],
#         [0.18891856],
#         [0.15798843],
#         [0.16088117],
#         [0.16021362],
#         [0.16488652],
#         [0.17601246],
#         [0.17423231],
#         [0.16911437],
#         [0.16866934],
#         [0.16110369],
#         [0.16866934],
#         [0.1753449 ],
#         [0.18647085],
#         [0.18224299],
#         [0.19136627],
#         [0.17334223],
#         [0.17400979],
#         [0.17311972],
#         [0.15665332],
#         [0.13106364],
#         [0.11593235],
#         [0.1223854 ],
#         [0.11615487],
#         [0.11281709],
#         [0.11682243],
#         [0.11481976],
#         [0.10947931],
#         [0.12127281],
#         [0.11927014],
#         [0.11125946],
#         [0.11392968],
#         [0.11214953],
#         [0.10636404],
#         [0.11259457],
#         [0.09790832],
#         [0.10013351],
#         [0.09679573],
#         [0.09968847],
#         [0.09679573],
#         [0.09790832],
#         [0.08811749],
#         [0.08811749],
#         [0.08055185],
#         [0.07387628],
#         [0.07209613],
#         [0.0623053 ],
#         [0.07031598],
#         [0.07343124],
#         [0.08633734],
#         [0.07899421],
#         [0.09701825],
#         [0.09701825],
#         [0.09790832],
#         [0.08678238],
#         [0.09279039],
#         [0.09368046],
#         [0.09301291],
#         [0.09501558],
#         [0.08900757],
#         [0.09501558],
#         [0.09256787],
#         [0.08210948],
#         [0.082332  ],
#         [0.09635069],
#         [0.08878505],
#         [0.08811749],
#         [0.06920338],
#         [0.05785492],
#         [0.06519804],
#         [0.07031598],
#         [0.0658656 ],
#         [0.07610147],
#         [0.07076101],
#         [0.08322207],
#         [0.0894526 ],
#         [0.07476636],
#         [0.08900757],
#         [0.09345794],
#         [0.06675567],
#         [0.12016021],
#         [0.10992434],
#         [0.12461059],
#         [0.13840676],
#         [0.15576324],
#         [0.16199377],
#         [0.16755674],
#         [0.15576324],
#         [0.16243881],
#         [0.20026702],
#         [0.20493992],
#         [0.22207388],
#         [0.22007121],
#         [0.23564753],
#         [0.21806854],
#         [0.21339564],
#         [0.22251891],
#         [0.2047174 ],
#         [0.21562083],
#         [0.2176235 ],
#         [0.21940365],
#         [0.22674677],
#         [0.17334223],
#         [0.17578994],
#         [0.16889186],
#         [0.15109034],
#         [0.19982198],
#         [0.20071206],
#         [0.16866934],
#         [0.1800178 ],
#         [0.15976858],
#         [0.16088117],
#         [0.15576324],
#         [0.16332888],
#         [0.16399644],
#         [0.15732087],
#         [0.15287049],
#         [0.14330218],
#         [0.1553182 ],
#         [0.17445483],
#         [0.17467735],
#         [0.17245216],
#         [0.17311972],
#         [0.17089453],
#         [0.16577659],
#         [0.16510903],
#         [0.16310636],
#         [0.1671117 ],
#         [0.16911437],
#         [0.17979528],
#         [0.16644415],
#         [0.1588785 ],
#         [0.17356475],
#         [0.16399644],
#         [0.15776591],
#         [0.15932354],
#         [0.15086782],
#         [0.15487316],
#         [0.15353805],
#         [0.1835781 ],
#         [0.18202047],
#         [0.15821095],
#         [0.15798843],
#         [0.14686248],
#         [0.15754339],
#         [0.16911437],
#         [0.17801513],
#         [0.16866934],
#         [0.15576324],
#         [0.12661326],
#         [0.13551402],
#         [0.12794838],
#         [0.12861593],
#         [0.14152203],
#         [0.12171785],
#         [0.12683578],
#         [0.13351135],
#         [0.13796173],
#         [0.13306631],
#         [0.13306631],
#         [0.13551402],
#         [0.13796173],
#         [0.1399644 ],
#         [0.13573654],
#         [0.13907432],
#         [0.14508233],
#         [0.12906097],
#         [0.1223854 ],
#         [0.11192701],
#         [0.10903427],
#         [0.09679573],
#         [0.07788162],
#         [0.10903427],
#         [0.10057855],
#         [0.10369381],
#         [0.09590565],
#         [0.10458389],
#         [0.10636404],
#         [0.10792167],
#         [0.11748999],
#         [0.08455719],
#         [0.09924344],
#         [0.10814419],
#         [0.07254117],
#         [0.0729862 ],
#         [0.07721406],
#         [0.07988429],
#         [0.06898086],
#         [0.06764575],
#         [0.0658656 ],
#         [0.06675567],
#         [0.06720071],
#         [0.07565643],
#         [0.07565643],
#         [0.08322207],
#         [0.07788162],
#         [0.07521139],
#         [0.07565643],
#         [0.07565643],
#         [0.08010681],
#         [0.07365376],
#         [0.06675567],
#         [0.06564308],
#         [0.0623053 ],
#         [0.07120605],
#         [0.07076101],
#         [0.06030263],
#         [0.0623053 ],
#         [0.07476636],
#         [0.08277704],
#         [0.07276368],
#         [0.08010681],
#         [0.08678238],
#         [0.08678238],
#         [0.07832666],
#         [0.07743658],
#         [0.07120605],
#         [0.08633734],
#         [0.07654651],
#         [0.07943925],
#         [0.07142857],
#         [0.07343124],
#         [0.06675567],
#         [0.06898086],
#         [0.06720071],
#         [0.07387628],
#         [0.08010681],
#         [0.08834001],
#         [0.08455719],
#         [0.08455719],
#         [0.07521139],
#         [0.07165109],
#         [0.07565643],
#         [0.08277704],
#         [0.08032933],
#         [0.07209613],
#         [0.06008011],
#         [0.05785492],
#         [0.0565198 ],
#         [0.05785492],
#         [0.05807744],
#         [0.06030263],
#         [0.0658656 ],
#         [0.05629729],
#         [0.05028927],
#         [0.03115265],
#         [0.03337784],
#         [0.03115265],
#         [0.00534045],
#         [0.00890076],
#         [0.02202937],
#         [0.02136182],
#         [0.01424121],
#         [0.02670227],
#         [0.01913663],
#         [0.00890076],
#         [0.01068091],
#         [0.        ],
#         [0.02091678],
#         [0.00934579],
#         [0.00111259],
#         [0.04316867],
#         [0.07788162],
#         [0.08900757],
#         [0.08923008],
#         [0.08411215],
#         [0.0894526 ],
#         [0.08923008],
#         [0.10858923],
#         [0.105919  ],
#         [0.09390298],
#         [0.0976858 ],
#         [0.0976858 ],
#         [0.10169114],
#         [0.09279039],
#         [0.08923008],
#         [0.09612817],
#         [0.08878505],
#         [0.11125946],
#         [0.14241211],
#         [0.12950601],
#         [0.17245216],
#         [0.1753449 ],
#         [0.17890521],
#         [0.16755674],
#         [0.18291055],
#         [0.19626168],
#         [0.18246551],
#         [0.19092123],
#         [0.19158879],
#         [0.19581664],
#         [0.17578994],
#         [0.18424566],
#         [0.18647085],
#         [0.17801513],
#         [0.17356475],
#         [0.18068536],
#         [0.17156208],
#         [0.17556742],
#         [0.15398309],
#         [0.13974188],
#         [0.14174455],
#         [0.12861593],
#         [0.14374722],
#         [0.12972853],
#         [0.14307966],
#         [0.14218959],
#         [0.13840676],
#         [0.13796173],
#         [0.14730752],
#         [0.14864263],
#         [0.15598576],
#         [0.15576324],
#         [0.14196707],
#         [0.14063195],
#         [0.13351135],
#         [0.14152203],
#         [0.12483311],
#         [0.11838006],
#         [0.13640409],
#         [0.1188251 ],
#         [0.11036938],
#         [0.11125946],
#         [0.10547397],
#         [0.10814419],
#         [0.09746328],
#         [0.105919  ],
#         [0.12794838],
#         [0.12906097],
#         [0.13484646],
#         [0.13796173],
#         [0.15131286],
#         [0.14641745],
#         [0.14597241],
#         [0.1588785 ],
#         [0.15754339],
#         [0.1588785 ],
#         [0.16332888],
#         [0.14107699],
#         [0.13618158],
#         [0.14241211],
#         [0.1388518 ],
#         [0.13351135],
#         [0.14040943],
#         [0.14241211],
#         [0.13796173],
#         [0.14196707],
#         [0.12950601],
#         [0.13128616],
#         [0.12661326],
#         [0.11548732],
#         [0.10858923],
#         [0.10458389],
#         [0.09790832],
#         [0.09701825],
#         [0.0905652 ],
#         [0.10324878],
#         [0.08923008],
#         [0.09345794],
#         [0.10658656],
#         [0.09368046],
#         [0.09390298],
#         [0.09701825],
#         [0.08455719],
#         [0.08500223],
#         [0.08188696],
#         [0.08277704],
#         [0.09590565],
#         [0.07899421],
#         [0.05829996],
#         [0.07009346],
#         [0.0658656 ],
#         [0.06831331],
#         [0.07231865],
#         [0.06653316],
#         [0.05829996],
#         [0.1152648 ],
#         [0.12683578],
#         [0.13484646],
#         [0.14018692],
#         [0.1388518 ],
#         [0.13128616],
#         [0.12550067],
#         [0.14018692],
#         [0.15442813],
#         [0.16110369],
#         [0.17356475],
#         [0.17779261],
#         [0.17356475],
#         [0.18335559],
#         [0.17979528],
#         [0.17089453],
#         [0.14686248],
#         [0.15442813],
#         [0.1564308 ],
#         [0.15487316],
#         [0.16733422],
#         [0.16844682],
#         [0.16444148],
#         [0.15131286],
#         [0.16510903],
#         [0.15665332],
#         [0.15976858],
#         [0.1599911 ],
#         [0.15353805],
#         [0.15131286],
#         [0.14196707],
#         [0.25144637],
#         [0.22719181],
#         [0.2412105 ],
#         [0.24032043],
#         [0.2412105 ],
#         [0.24076547],
#         [0.25456164],
#         [0.25589675],
#         [0.22852692],
#         [0.23119715],
#         [0.23898531],
#         [0.24855363],
#         [0.24788607],
#         [0.25834446],
#         [0.24432577],
#         [0.27503338],
#         [0.25812194],
#         [0.24877615],
#         [0.24098798],
#         [0.24032043],
#         [0.23920783],
#         [0.25033378],
#         [0.24299065],
#         [0.23943035],
#         [0.22741433],
#         [0.229417  ],
#         [0.22140632],
#         [0.23609257],
#         [0.24655096],
#         [0.25189141],
#         [0.25656431],
#         [0.25567423],
#         [0.24477081],
#         [0.2458834 ],
#         [0.25367156],
#         [0.24966622],
#         [0.25367156],
#         [0.24922118],
#         [0.2777036 ],
#         [0.27681353],
#         [0.29906542],
#         [0.28927459],
#         [0.27903872],
#         [0.25389408],
#         [0.25678683],
#         [0.28504673],
#         [0.29372497],
#         [0.28927459],
#         [0.26635514],
#         [0.26924789],
#         [0.27636849],
#         [0.26724522],
#         [0.270583  ],
#         [0.22696929],
#         [0.23943035],
#         [0.22251891],
#         [0.2140632 ],
#         [0.22429907],
#         [0.22407655],
#         [0.22874944],
#         [0.23364486],
#         [0.24699599],
#         [0.24699599],
#         [0.23831776],
#         [0.2329773 ],
#         [0.21895861],
#         [0.22096128],
#         [0.22296395],
#         [0.21584335],
#         [0.21228304],
#         [0.2211838 ],
#         [0.22518914],
#         [0.22541166],
#         [0.22741433],
#         [0.23164219],
#         [0.21806854],
#         [0.22162884],
#         [0.23564753],
#         [0.22029372],
#         [0.23676012],
#         [0.23898531],
#         [0.25144637],
#         [0.25144637],
#         [0.26034713],
#         [0.25300401],
#         [0.24143302],
#         [0.2258567 ],
#         [0.21962617],
#         [0.20404984],
#         [0.2305296 ],
#         [0.23342234],
#         [0.24477081],
#         [0.28771696],
#         [0.28971963],
#         [0.28971963],
#         [0.32042724],
#         [0.32599021],
#         [0.31308411],
#         [0.30907877],
#         [0.28927459],
#         [0.29372497],
#         [0.28170895],
#         [0.28682688],
#         [0.28037383],
#         [0.26524255],
#         [0.2741433 ],
#         [0.28482421],
#         [0.28037383],
#         [0.26390743],
#         [0.29817534],
#         [0.29105474],
#         [0.32398754],
#         [0.30551847],
#         [0.3153093 ],
#         [0.24032043],
#         [0.22830441],
#         [0.20916778],
#         [0.20026702],
#         [0.20649755],
#         [0.20916778],
#         [0.22919448],
#         [0.24032043],
#         [0.24165554],
#         [0.24699599],
#         [0.23587005],
#         [0.22919448],
#         [0.2340899 ],
#         [0.2222964 ],
#         [0.19136627],
#         [0.1929239 ],
#         [0.20026702],
#         [0.19581664],
#         [0.18914108],
#         [0.19047619],
#         [0.17400979],
#         [0.18713841],
#         [0.18713841],
#         [0.19603916],
#         [0.20293725],
#         [0.20672007],
#         [0.22007121],
#         [0.22251891],
#         [0.22251891],
#         [0.23809524],
#         [0.24410325],
#         [0.24009791],
#         [0.2458834 ],
#         [0.21361816],
#         [0.22363151],
#         [0.22630174],
#         [0.21895861],
#         [0.23186471],
#         [0.22140632],
#         [0.20605251],
#         [0.21806854],
#         [0.22696929],
#         [0.23141967],
#         [0.21562083],
#         [0.20916778],
#         [0.17734757],
#         [0.17801513],
#         [0.18246551],
#         [0.17601246],
#         [0.17868269],
#         [0.18313307],
#         [0.17801513],
#         [0.16777926],
#         [0.17890521],
#         [0.17668002],
#         [0.17356475],
#         [0.19136627],
#         [0.19158879],
#         [0.18157543],
#         [0.18202047],
#         [0.18024032],
#         [0.17133956],
#         [0.17111704],
#         [0.15042279],
#         [0.16444148],
#         [0.16533155],
#         [0.17222964],
#         [0.17890521],
#         [0.17690254],
#         [0.17022697],
#         [0.16177125],
#         [0.16622163],
#         [0.16065866],
#         [0.1671117 ],
#         [0.17156208],
#         [0.18246551],
#         [0.188251  ],
#         [0.18335559],
#         [0.18402314],
#         [0.17556742],
#         [0.18380062],
#         [0.17868269],
#         [0.17000445],
#         [0.16844682],
#         [0.17067201],
#         [0.17267468],
#         [0.164664  ],
#         [0.16866934],
#         [0.17801513],
#         [0.19692924],
#         [0.20493992],
#         [0.20182466],
#         [0.20249221],
#         [0.19247886],
#         [0.20694259],
#         [0.21918113],
#         [0.22185136],
#         [0.22274143],
#         [0.23631509],
#         [0.24499332],
#         [0.24210058],
#         [0.24076547],
#         [0.24032043],
#         [0.24009791],
#         [0.22897196],
#         [0.25589675],
#         [0.25745438],
#         [0.25144637],
#         [0.24721851],
#         [0.25723186],
#         [0.24922118],
#         [0.23319982],
#         [0.22919448],
#         [0.19670672],
#         [0.20271473],
#         [0.188251  ],
#         [0.18291055],
#         [0.18802848],
#         [0.19136627],
#         [0.19492657],
#         [0.2000445 ],
#         [0.19470405],
#         [0.20516244],
#         [0.19492657],
#         [0.19848687],
#         [0.19359146],
#         [0.2047174 ],
#         [0.20560748],
#         [0.20026702],
#         [0.18691589],
#         [0.19270138],
#         [0.17356475],
#         [0.17601246],
#         [0.18402314],
#         [0.18736093],
#         [0.19247886],
#         [0.2047174 ],
#         [0.17578994],
#         [0.19158879],
#         [0.23141967],
#         [0.24076547],
#         [0.25545171],
#         [0.25456164],
#         [0.27325323],
#         [0.28793947],
#         [0.29149978],
#         [0.28927459],
#         [0.27147308],
#         [0.27592345],
#         [0.2670227 ],
#         [0.26835781],
#         [0.27147308],
#         [0.28126391],
#         [0.24922118],
#         [0.26301736],
#         [0.25545171],
#         [0.27369826],
#         [0.26791277],
#         [0.24966622],
#         [0.25367156],
#         [0.25745438],
#         [0.2587895 ],
#         [0.23587005],
#         [0.23453494],
#         [0.24032043]]))

# %% [markdown]
# # Convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, time_step=1):
    train_X, train_Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        train_X.append(a)
        train_Y.append(dataset[i + time_step, 0])
    return numpy.array(train_X), numpy.array(train_Y)

# %% [markdown]
# # Reshape into X=t,t+1,t+2,t+3 and Y=t+4

# %%
import numpy
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (825, 100)
# (825,)
# (None, None)

# %% [markdown]
# # Reshape input to be [samples, time steps, features] which is required for LSTM

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# # Create the Stacked LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 286ms/step - loss: 6.4486e-04 - val_loss: 4.6781e-04
# Epoch 85/100
# 13/13 [==============================] - 4s 281ms/step - loss: 6.0142e-04 - val_loss: 4.5697e-04
# Epoch 86/100
# 13/13 [==============================] - 4s 289ms/step - loss: 6.0341e-04 - val_loss: 4.6589e-04
# Epoch 87/100
# 13/13 [==============================] - 3s 264ms/step - loss: 5.9130e-04 - val_loss: 4.6532e-04
# Epoch 88/100
# 13/13 [==============================] - 3s 267ms/step - loss: 5.5937e-04 - val_loss: 4.4017e-04
# Epoch 89/100
# 13/13 [==============================] - 4s 298ms/step - loss: 5.6040e-04 - val_loss: 4.8494e-04
# Epoch 90/100
# 13/13 [==============================] - 4s 296ms/step - loss: 5.4237e-04 - val_loss: 4.3026e-04
# Epoch 91/100
# 13/13 [==============================] - 4s 277ms/step - loss: 5.2921e-04 - val_loss: 4.3722e-04
# Epoch 92/100
# 13/13 [==============================] - 3s 260ms/step - loss: 5.1411e-04 - val_loss: 4.1297e-04
# Epoch 93/100
# 13/13 [==============================] - 3s 257ms/step - loss: 5.7913e-04 - val_loss: 4.0627e-04
# Epoch 94/100
# 13/13 [==============================] - 4s 274ms/step - loss: 5.5425e-04 - val_loss: 4.9562e-04
# Epoch 95/100
# 13/13 [==============================] - 4s 277ms/step - loss: 5.2201e-04 - val_loss: 4.1060e-04
# Epoch 96/100
# 13/13 [==============================] - 3s 256ms/step - loss: 5.1698e-04 - val_loss: 5.0997e-04
# Epoch 97/100
# 13/13 [==============================] - 3s 266ms/step - loss: 5.5823e-04 - val_loss: 4.3548e-04
# Epoch 98/100
# 13/13 [==============================] - 3s 257ms/step - loss: 5.9231e-04 - val_loss: 4.5516e-04
# Epoch 99/100
# 13/13 [==============================] - 4s 282ms/step - loss: 4.9752e-04 - val_loss: 4.8665e-04
# Epoch 100/100
# 13/13 [==============================] - 4s 280ms/step - loss: 5.9046e-04 - val_loss: 4.9372e-04

# %%
import tensorflow as tf

# %% [markdown]
# # Lets Do the prediction and check performance metrics

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# 26/26 [==============================] - 4s 52ms/step
# 7/7 [==============================] - 0s 46ms/step

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %% [markdown]
# # Calculate RMSE performance metrics

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 173.5247590542388

# %% [markdown]
# # Test Data RMSE

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 150.26222710356384

# %% [markdown]
# # shift test predictions for plotting

# %%
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan

# %% [markdown]
# # Plot baseline and predictions

# %%
pred  = scaler.inverse_transform(df2)
plt.plot(pred,color='blue')
plt.show()

# %%
plt.plot(pred,color='red')
plt.show()
plt.plot(pred,color='green')
plt.show()

# %%
plt.plot(train_predict,color='red')
plt.plot(test_predict,color='green')
plt.show()

# %%
plt.plot(pred,color='blue')
plt.plot(train_predict,color='red')
plt.plot(test_predict,color='green')
plt.show()

# %%
len(test_data)
# Out:
# 309

# %%
x_input=test_data[341:].reshape(1,-1)
x_input.shape
# Out:
# (1, 0)

# %% [markdown]
# # Save the Model

# %%
model.save("saved_model.h5")
